# %%
import numpy as np
import scipy
import scipy.stats
import glob
import os
import itertools

# %%
ROOTPATH = os.path.sep.join([os.environ['HOME'], 'git/beat_onset/data/results'])

# %%
# To match holzapfel'12 eval on SMC2
N_BINS = 40

# %%
DATASETS = ['mirex2006', 'rwcj', 'jazz_roger', 'smc_dataset2']
#DATASETS = ['smc_dataset2']

# %%
SCORENAMES = ['Cemgil', 'CMLc', 'CMLt', 'AMLc', 'AMLt', 'F-Meas', 'Goto', 'I.Gain', 'P_score']

# %%
SPECS = ['full', 'harmonic', 'percussive', 'lowrank']
#SPECS = ['lowrank']
SCALE = ['log']
#SCALE = ['linear', 'log', 'cbrt']
#AGGS  = ['sum', 'q=0.25', 'q=0.50', 'q=0.75']
AGGS  = ['sum', 'q=0.50']

# %%
def load_beatroot_scores(data):
    path = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', 'beatroot.scores.txt'])])
    
    files = sorted(glob.glob(path))
    return load_scores(files)
    
def load_our_scores(data, spec, scale, agg):
    path   = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', scale, agg, spec, 'scores.txt'])])
    
    files  = sorted(glob.glob(path))
    return load_scores(files)

def load_scores(files):
    scores = None
    
    for f in files:
        new_scores = np.loadtxt(f, delimiter=',')
        if scores is None:
            scores = new_scores
        else:
            scores = np.vstack([scores, new_scores])
            
    # Un-normalize I.Gain
    scores[:,-2] *= np.log2(N_BINS)
    
    return scores

# %%
def get_top_sig(perfs, idx, p=0.05):
    
    # Pluck out the relevant algorithm
    data = {}
    mean = {}
    best_mean = -np.inf
    best_alg  = None
    n_algs    = len(perfs)
    #n_algs = 2
    
    for k in perfs:
        data[k] = perfs[k][:, idx]
        mean[k] = np.mean(data[k])
        if mean[k] > best_mean:
            best_mean = mean[k]
            best_alg = k
    
    
    
    # Compute pairwise tests against the best
    sigdiff = {}
    for k in perfs:
        if k == best_alg:
            sigdiff[k] = 1.0
            continue
        # Get the p-value
        _z, _p = scipy.stats.wilcoxon(data[best_alg], data[k])
        
        sigdiff[k] = _p
        
        
    # Print the results
    ordering = [(v, k) for k, v in mean.iteritems()]
    ordering.sort(reverse=True)
    
    print u'%s\tp-value\t\tSigDif\tAlgorithm' % (SCORENAMES[idx])
    print '-' * 64
    for (v, k) in ordering:
        print '%.3f\t%.2e\t%r\t%s' % (v, sigdiff[k], sigdiff[k] * (n_algs -1) < p, k)

# %%
def plot_boxes(data, metrics=None):
    figure(figsize=(10,5))
    if metrics is None:
        metrics = range(len(SCORENAMES))
    
    for j,i in enumerate(metrics, 1):
        subplot(len(metrics)/3, 3, j)
        my_data = []
        leg = []
        for k in sorted(data.keys()):
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data)
        xticks(range(1, 1+len(data)), leg, rotation=-45, horizontalalignment='left')
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(SCORENAMES[i])

# %%
scores = {}
for (agg, spec) in itertools.product(AGGS, SPECS):
    key = agg.replace('q=0.50', 'med')
    scores['-'.join([key, spec])] = load_our_scores(DATASETS[3], spec, SCALE[-1], agg)

# %%
print DATASETS[3]
for idx in [4,5,7]:
    get_top_sig(scores, idx)
    print
# Out:
# smc_dataset2
# AMLt	p-value		SigDif	Algorithm
# ----------------------------------------------------------------
# 0.364	1.00e+00	False	med-percussive
# 0.336	1.21e-02	False	med-full
# 0.329	1.34e-05	True	med-lowrank
# 0.329	3.12e-04	True	med-harmonic
# 0.313	8.36e-03	False	sum-harmonic
# 0.312	6.26e-03	True	sum-full
# 0.307	7.52e-03	False	sum-lowrank
# 0.304	1.65e-02	False	sum-percussive
#
# F-Meas	p-value		SigDif	Algorithm
# ----------------------------------------------------------------
# 0.381	1.00e+00	False	med-percussive
# 0.374	4.10e-03	True	med-full
# 0.372	3.21e-04	True	med-lowrank
# 0.368	5.10e-04	True	med-harmonic
# 0.363	2.45e-03	True	sum-harmonic
# 0.362	3.34e-03	True	sum-full
# 0.357	1.13e-03	True	sum-percussive
# 0.356	4.32e-04	True	sum-lowrank
#
# I.Gain	p-value		SigDif	Algorithm
# ----------------------------------------------------------------
# 0.946	1.00e+00	False	med-percussive
# 0.916	3.29e-01	False	med-harmonic
# 0.916	1.67e-01	False	med-full
# 0.901	1.26e-03	True	med-lowrank
# 0.839	9.33e-04	True	sum-full
# 0.835	5.85e-04	True	sum-harmonic
# 0.832	4.03e-05	True	sum-lowrank
# 0.811	1.02e-07	True	sum-percussive

# %%
plot_boxes(scores, [4,5,7])

# %% [markdown]
# # Aggregate statistics

# %%
def evaluate_our_predictions(data, spec, scale, agg):
    path = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', scale, agg, spec, 'scores.txt'])])
    
    files = sorted(glob.glob(path))
    print data, spec, agg, scale
    evaluate_predictions(files)

def evaluate_beatroot_predictions(data):
    path = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', 'beatroot.scores.txt'])])
    
    files = sorted(glob.glob(path))
    print data, 'BeatRoot'
    
    evaluate_predictions(files)
    
def evaluate_predictions(files):
    scores = None
    
    for f in files:
        values = np.loadtxt(f, delimiter=',')
        if scores is None:
            scores = values
        else:
            scores = np.vstack([scores, values])
    
    # Un-normalize information gain
    scores[:,-2] *= np.log2(N_BINS)
    n = scores.shape[0]
    errs = np.std(scores, axis=0) / np.sqrt(n)
    scores = np.mean(scores, axis=0)
    
    print ' '.join(map(lambda x: '   %0.3f' %x, scores))
    print ' '.join(map(lambda x: ' +-%0.3f' %x, errs))

# %%
print ' '.join(map(lambda x: '%8s' %x, SCORENAMES))
print '-' * 80
for data in DATASETS:
    
    evaluate_beatroot_predictions(data)
    print
# Out:
#   Cemgil     CMLc     CMLt     AMLc     AMLt   F-Meas     Goto   I.Gain  P_score
# --------------------------------------------------------------------------------
# smc_dataset2
#  BeatRoot
#    0.243    0.045    0.068    0.136    0.276    0.322    0.032    0.669    0.424
#  +-0.011  +-0.011  +-0.014  +-0.015  +-0.019  +-0.013  +-0.012  +-0.046  +-0.009

# %%
print ' '.join(map(lambda x: '%8s' %x, SCORENAMES))
print '-' * 80
for (data, agg, spec, scale) in itertools.product(DATASETS, AGGS, SPECS, SCALE):
    evaluate_our_predictions(data, spec, scale, agg)
    print
# Out:
#   Cemgil     CMLc     CMLt     AMLc     AMLt   F-Meas     Goto   I.Gain  P_score
# --------------------------------------------------------------------------------
# smc_dataset2 full sum linear
#    0.222    0.075    0.121    0.128    0.276    0.329    0.055    0.846    0.451
#  +-0.009  +-0.014  +-0.017  +-0.013  +-0.018  +-0.013  +-0.016  +-0.048  +-0.011
#
# smc_dataset2 full sum log
#    0.267    0.074    0.122    0.154    0.312    0.362    0.051    0.839    0.460
#  +-0.011  +-0.013  +-0.018  +-0.015  +-0.019  +-0.014  +-0.015  +-0.040  +-0.011
#
# smc_dataset2 full sum cbrt
#    0.256    0.076    0.125    0.146    0.305    0.356    0.060    0.871    0.461
#  +-0.010  +-0.013  +-0.018  +-0.014  +-0.019  +-0.014  +-0.016  +-0.044  +-0.011
#
# smc_dataset2 harmonic sum linear
#    0.206    0.074    0.124    0.120    0.260    0.312    0.046    0.821    0.452
#  +-0.008  +-0.013  +-0.017  +-0.013  +-0.017  +-0.013  +-0.014  +-0.045  +-0.011
#
# smc_dataset2 harmonic sum log
#    0.266    0.077    0.124    0.153    0.313    0.363    0.060    0.835    0.463
#  +-0.011  +-0.014  +-0.018  +-0.015  +-0.019  +-0.014  +-0.016  +-0.039  +-0.011
#
# smc_dataset2 harmonic sum cbrt
#    0.247    0.065    0.113    0.137    0.297    0.345    0.046    0.833    0.455
#  +-0.009  +-0.012  +-0.017  +-0.013  +-0.019  +-0.013  +-0.014  +-0.040  +-0.011
#
# smc_dataset2 percussive sum linear
#    0.239    0.082    0.123    0.155    0.306    0.342    0.065    0.874    0.459
#  +-0.010  +-0.015  +-0.017  +-0.016  +-0.019  +-0.014  +-0.017  +-0.052  +-0.011
#
# smc_dataset2 percussive sum log
#    0.266    0.071    0.114    0.151    0.304    0.357    0.051    0.811    0.454
#  +-0.010  +-0.013  +-0.017  +-0.014  +-0.019  +-0.013  +-0.015  +-0.040  +-0.011
#
# smc_dataset2 percussive sum cbrt
#    0.279    0.104    0.171    0.187    0.353    0.383    0.069    0.944    0.481
#  +-0.011  +-0.015  +-0.020  +-0.016  +-0.021  +-0.014  +-0.017  +-0.047  +-0.013
#
# smc_dataset2 lowrank q=0.50 linear
#    0.237    0.071    0.124    0.164    0.305    0.335    0.046    0.871    0.448
#  +-0.009  +-0.012  +-0.017  +-0.016  +-0.019  +-0.013  +-0.014  +-0.043  +-0.011
#
# smc_dataset2 lowrank q=0.50 log
#    0.273    0.089    0.150    0.169    0.329    0.372    0.060    0.901    0.472
#  +-0.010  +-0.014  +-0.019  +-0.015  +-0.020  +-0.014  +-0.016  +-0.043  +-0.012
#
# smc_dataset2 lowrank q=0.50 cbrt
#    0.266    0.093    0.160    0.175    0.338    0.369    0.065    0.921    0.478
#  +-0.011  +-0.014  +-0.019  +-0.016  +-0.020  +-0.014  +-0.017  +-0.045  +-0.012

# %%
import librosa
import functools
specshow = functools.partial(imshow, aspect='auto', interpolation='nearest', origin='lower', cmap='gray_r')

# %%
def odf_sum(S):
    o = np.sum(np.maximum(0.0, np.diff(S, axis=1)), axis=0)
    o = o - o.min()
    o = o / o.max()
    
    return o

def odf_med(S):
    o = np.median(np.maximum(0.0, np.diff(S, axis=1)), axis=0)
    o = o - o.min()
    o = o / o.max()
    return o

# %%
OFFSET = 10.0
DURATION = 10.0
y, sr = librosa.load('/home/bmcfee/data/SMC_Mirex/SMC_MIREX_Audio/SMC_113.wav', duration=DURATION, offset=OFFSET)
S, phase = librosa.magphase(librosa.stft(y, n_fft=2048, hop_length=64))
S = S / S.max()

# %%
beat_times = np.loadtxt('/home/bmcfee/data/SMC_Mirex/SMC_MIREX_Annotations/SMC_113_3_1_1_a.txt')
beat_times = beat_times[(OFFSET <= beat_times) & (beat_times <= OFFSET + DURATION)]
beat_times = beat_times - OFFSET

# %%
beats = np.round(beat_times * sr / 64)

# %%
M = librosa.feature.melfb(sr, n_fft=2048, n_mels=128, fmax=8000)
M = M[:,:1025]

# %%
figure(figsize=(8,6))
subplot(411)
specshow(librosa.logamplitude(M.dot(S)), vmax=0, vmin=-40.0)
xticks([]), yticks([])
vlines(beats, 0, 127, colors='r')
title('Mel spectrogram')
subplot(412)
plot(odf_sum(librosa.logamplitude(M.dot(S)))), axis('tight')
xticks([]), yticks([])
vlines(beats, 0, 1, colors='r')
title('Sum onset aggregation')
subplot(413)
plot(odf_med(librosa.logamplitude(M.dot(S)))), axis('tight')
xticks([]), yticks([])
title('Median onset aggregation')
vlines(beats, 0, 1, colors='r')
subplot(414)
plot(odf_med(scipy.signal.medfilt2d(librosa.logamplitude(M.dot(S)), kernel_size=(1,5)))), axis('tight')
xticks([]), yticks([])
title('Median onset aggregation - median filter')
vlines(beats, 0, 1, colors='r')
