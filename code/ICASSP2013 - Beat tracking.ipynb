# %%
import numpy as np
import scipy
import scipy.stats
import glob
import os
import itertools

# %%
ROOTPATH = os.path.sep.join([os.environ['HOME'], 'git/beat_onset/data/results'])

# %%
# To match holzapfel'12 eval on SMC2
N_BINS = 40

# %%
#DATASETS = ['mirex2006', 'rwcj', 'jazz_roger', 'smc_dataset2']
DATASETS = ['smc_dataset2']

# %%
SCORENAMES = ['Cemgil', 'CMLc', 'CMLt', 'AMLc', 'AMLt', 'F-Meas', 'Goto', 'I.Gain', 'P_score']

# %%
SPECS = ['full', 'harmonic', 'percussive', 'lowrank']
#SPECS = ['lowrank']
SCALE = ['log']
#SCALE = ['linear', 'log', 'cbrt']
#AGGS  = ['sum', 'q=0.25', 'q=0.50', 'q=0.75']
AGGS  = ['sum', 'q=0.50']

# %%
def load_comparison_scores(data, key='Ellis'):
    path = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', key, 'scores.txt'])])
    
    files = sorted(glob.glob(path))
    return load_scores(files)
    
def load_our_scores(data, spec, scale, agg):
    path   = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', scale, agg, spec, 'scores.txt'])])
    
    files  = sorted(glob.glob(path))
    return load_scores(files)

def load_scores(files, limit=-19):
    scores = None
    
    for f in files[:limit]:
        new_scores = np.loadtxt(f, delimiter=',')
        if scores is None:
            scores = new_scores
        else:
            scores = np.vstack([scores, new_scores])
            
    # Un-normalize I.Gain
    scores[:,-2] *= np.log2(N_BINS)
    
    return scores

# %%
def get_top_sig(perfs, idx, p=0.05):
    
    # Pluck out the relevant algorithm
    data = {}
    mean = {}
    best_mean = -np.inf
    best_alg  = None
    n_algs    = len(perfs)
    #n_algs = 2
    
    for k in perfs:
        data[k] = perfs[k][:, idx]
        mean[k] = np.mean(data[k])
        if mean[k] > best_mean:
            best_mean = mean[k]
            best_alg = k
    
    
    
    # Compute pairwise tests against the best
    sigdiff = {}
    for k in perfs:
        if k == best_alg:
            sigdiff[k] = 1.0
            continue
        # Get the p-value
        _z, _p = scipy.stats.wilcoxon(data[best_alg], data[k])
        #_z, _p = scipy.stats.ttest_rel(data[best_alg], data[k])
        
        sigdiff[k] = _p
        
        
    # Print the results
    ordering = [(v, k) for k, v in mean.iteritems()]
    ordering.sort(reverse=True)
    
    print u'%s\tp-value\t\tSigDif\tAlgorithm' % (SCORENAMES[idx])
    print '-' * 64
    for (v, k) in ordering:
        print '%.3f\t%.2e\t%r\t%s' % (v, sigdiff[k], sigdiff[k] * (n_algs -1) < p, k)

# %%
def plot_boxes(data, metrics=None):
    figure(figsize=(10,5))
    if metrics is None:
        metrics = range(len(SCORENAMES))
    
    for j,i in enumerate(metrics, 1):
        subplot(len(metrics)/3, 3, j)
        my_data = []
        leg = []
        for k in sorted(data.keys()):
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data, bootstrap=10000)
        xticks(range(1, 1+len(data)), leg, rotation=-45, horizontalalignment='left')
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(SCORENAMES[i])

# %%
def get_worst_examples(perfs, algorithm, idx, k=10, rev=False):
    #files = sorted(map(os.path.basename, glob.glob('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, algorithm))))
    
    
    indices = np.argsort(perfs[algorithm][:, idx])
    if rev:
        indices = indices[-k:][::-1]
    else:
        indices = indices[:k]
        
    print '%s\t%s' % (SCORENAMES[idx], algorithm)
    for v in indices:
        print '%.3f\t%s' % (perfs[algorithm][v, idx], tracks[v])

# %%
scores = {}
for alg in ['Ellis', 'Boeck', 'Klapuri', 'Degara']:#, 'Davies_standard']:
    scores[alg] = load_comparison_scores(DATASETS[-1], key=alg)
    
for (agg, spec) in itertools.product(AGGS, SPECS):
    key = agg.replace('q=0.50', 'med')
    scores['-'.join([key, spec])] = load_our_scores(DATASETS[-1], spec, SCALE[-1], agg)

# %%
for alg in ['sum-full', 'med-full']:
    get_worst_examples(scores, alg, 7, k=10, rev=True)
    print
# Out:
# I.Gain	sum-full
# 2.043	SMC_013
# 2.011	SMC_014
# 1.881	SMC_096
# 1.838	SMC_034
# 1.673	SMC_082
# 1.640	SMC_262
# 1.636	SMC_024
# 1.630	SMC_059
# 1.625	SMC_036
# 1.598	SMC_065
#
# I.Gain	med-full
# 2.539	SMC_001
# 2.121	SMC_269
# 2.082	SMC_068
# 2.080	SMC_016
# 2.054	SMC_153
# 2.052	SMC_193
# 2.051	SMC_014
# 1.843	SMC_255
# 1.734	SMC_079
# 1.724	SMC_173

# %%
print DATASETS[-1]
for idx in [4,5,7]:
    get_top_sig(scores, idx)
    print
# Out:
# smc_dataset2
# AMLt	p-value		SigDif	Algorithm
# ----------------------------------------------------------------
# 0.364	1.00e+00	False	med-percussive
# 0.339	3.07e-03	True	Klapuri
# 0.336	1.21e-02	False	med-full
# 0.334	1.16e-02	False	Degara
# 0.329	1.34e-05	True	med-lowrank
# 0.329	3.12e-04	True	med-harmonic
# 0.313	8.36e-03	False	sum-harmonic
# 0.312	6.26e-03	False	sum-full
# 0.307	7.52e-03	False	sum-lowrank
# 0.304	1.65e-02	False	sum-percussive
# 0.261	3.78e-09	True	Boeck
# 0.208	9.04e-16	True	Ellis
#
# F-Meas	p-value		SigDif	Algorithm
# ----------------------------------------------------------------
# 0.401	1.00e+00	False	Boeck
# 0.381	2.58e-02	False	med-percussive
# 0.374	6.42e-04	True	med-full
# 0.372	9.69e-04	True	med-lowrank
# 0.368	1.18e-04	True	med-harmonic
# 0.363	7.95e-07	True	Klapuri
# 0.363	6.91e-05	True	sum-harmonic
# 0.362	4.76e-05	True	sum-full
# 0.357	7.66e-06	True	sum-percussive
# 0.356	2.26e-06	True	sum-lowrank
# 0.352	1.45e-07	True	Ellis
# 0.348	1.48e-09	True	Degara
#
# I.Gain	p-value		SigDif	Algorithm
# ----------------------------------------------------------------
# 0.946	1.00e+00	False	med-percussive
# 0.926	3.31e-02	False	Klapuri
# 0.917	1.64e-01	False	Boeck
# 0.916	3.29e-01	False	med-harmonic
# 0.916	1.67e-01	False	med-full
# 0.901	1.26e-03	True	med-lowrank
# 0.888	1.80e-04	True	Degara
# 0.839	9.33e-04	True	sum-full
# 0.835	5.85e-04	True	sum-harmonic
# 0.832	4.03e-05	True	sum-lowrank
# 0.811	1.02e-07	True	sum-percussive
# 0.607	2.23e-20	True	Ellis

# %%
plot_boxes(scores, [4,5,7])

# %% [markdown]
# # Aggregate statistics

# %%
def evaluate_our_predictions(data, spec, scale, agg):
    path = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', scale, agg, spec, 'scores.txt'])])
    
    files = sorted(glob.glob(path))
    print data, spec, agg, scale
    evaluate_predictions(files)

def evaluate_beatroot_predictions(data):
    path = os.path.sep.join([ROOTPATH, data, os.path.extsep.join(['*', 'beatroot.scores.txt'])])
    
    files = sorted(glob.glob(path))
    print data, 'BeatRoot'
    
    evaluate_predictions(files)
    
def evaluate_predictions(files):
    scores = None
    
    for f in files:
        values = np.loadtxt(f, delimiter=',')
        if scores is None:
            scores = values
        else:
            scores = np.vstack([scores, values])
    
    # Un-normalize information gain
    scores[:,-2] *= np.log2(N_BINS)
    n = scores.shape[0]
    errs = np.std(scores, axis=0) / np.sqrt(n)
    scores = np.mean(scores, axis=0)
    
    print ' '.join(map(lambda x: '   %0.3f' %x, scores))
    print ' '.join(map(lambda x: ' +-%0.3f' %x, errs))

# %%
print ' '.join(map(lambda x: '%8s' %x, SCORENAMES))
print '-' * 80
for data in DATASETS:
    
    evaluate_beatroot_predictions(data)
    print
# Out:
#   Cemgil     CMLc     CMLt     AMLc     AMLt   F-Meas     Goto   I.Gain  P_score
# --------------------------------------------------------------------------------
# smc_dataset2
#  BeatRoot
#    0.243    0.045    0.068    0.136    0.276    0.322    0.032    0.669    0.424
#  +-0.011  +-0.011  +-0.014  +-0.015  +-0.019  +-0.013  +-0.012  +-0.046  +-0.009

# %%
print ' '.join(map(lambda x: '%8s' %x, SCORENAMES))
print '-' * 80
for (data, agg, spec, scale) in itertools.product(DATASETS, AGGS, SPECS, SCALE):
    evaluate_our_predictions(data, spec, scale, agg)
    print
# Out:
#   Cemgil     CMLc     CMLt     AMLc     AMLt   F-Meas     Goto   I.Gain  P_score
# --------------------------------------------------------------------------------
# smc_dataset2 full sum log
#    0.267    0.075    0.123    0.155    0.312    0.363    0.055    0.842    0.460
#  +-0.011  +-0.013  +-0.018  +-0.015  +-0.020  +-0.014  +-0.016  +-0.041  +-0.011
#
# smc_dataset2 harmonic sum log
#    0.261    0.072    0.116    0.146    0.303    0.356    0.060    0.814    0.457
#  +-0.010  +-0.013  +-0.017  +-0.014  +-0.019  +-0.013  +-0.016  +-0.039  +-0.011
#
# smc_dataset2 percussive sum log
#    0.267    0.073    0.118    0.152    0.310    0.360    0.051    0.823    0.457
#  +-0.011  +-0.013  +-0.017  +-0.014  +-0.019  +-0.013  +-0.015  +-0.041  +-0.011
#
# smc_dataset2 lowrank sum log
#    0.273    0.081    0.131    0.163    0.323    0.367    0.055    0.865    0.462
#  +-0.011  +-0.014  +-0.018  +-0.015  +-0.020  +-0.014  +-0.016  +-0.043  +-0.012
#
# smc_dataset2 full q=0.50 log
#    0.270    0.100    0.170    0.169    0.322    0.373    0.055    0.906    0.475
#  +-0.010  +-0.014  +-0.019  +-0.015  +-0.020  +-0.014  +-0.016  +-0.044  +-0.012
#
# smc_dataset2 harmonic q=0.50 log
#    0.260    0.094    0.159    0.162    0.306    0.360    0.046    0.887    0.465
#  +-0.011  +-0.014  +-0.019  +-0.015  +-0.020  +-0.014  +-0.014  +-0.043  +-0.012
#
# smc_dataset2 percussive q=0.50 log
#    0.272    0.100    0.163    0.177    0.332    0.371    0.078    0.917    0.470
#  +-0.010  +-0.014  +-0.019  +-0.015  +-0.020  +-0.014  +-0.018  +-0.044  +-0.012
#
# smc_dataset2 lowrank q=0.50 log
#    0.270    0.098    0.165    0.173    0.326    0.374    0.051    0.904    0.471
#  +-0.010  +-0.014  +-0.019  +-0.015  +-0.020  +-0.014  +-0.015  +-0.042  +-0.012

# %%
import librosa
import functools
specshow = functools.partial(imshow, aspect='auto', interpolation='nearest', origin='lower', cmap='gray_r')

# %%
def get_beats(filename, offset, duration):
    beat_times = np.loadtxt(filename)
    beat_times = beat_times[(offset <= beat_times) & (beat_times <= offset + duration)]
    beat_times = beat_times - offset
    
    return np.round(beat_times * sr / 64.)

# %%
def odf_sum(S):
    o = np.sum(np.maximum(0.0, np.diff(S, axis=1)), axis=0)
    o = o - o.min()
    o = o / o.max()
    
    return o

def odf_med(S):
    o = np.median(np.maximum(0.0, np.diff(S, axis=1)), axis=0)
    o = o - o.min()
    o = o / o.max()
    return o

# %%
OFFSET = 21.0
DURATION = 7.0
y, sr = librosa.load('/home/bmcfee/data/SMC_Mirex/SMC_MIREX_Audio/SMC_275.wav', duration=DURATION, offset=OFFSET)
S, phase = librosa.magphase(librosa.stft(y, n_fft=2048, hop_length=64))
S = S / S.max()

# %%
beats = get_beats('/home/bmcfee/data/SMC_Mirex/SMC_annotations_reformat/SMC_275.txt', OFFSET, DURATION)
beats_pred_sum = get_beats('/home/bmcfee/git/beat_onset/data/predictions/smc_dataset2/SMC_275.log.sum.full.csv', OFFSET, DURATION)
beats_pred_med = get_beats('/home/bmcfee/git/beat_onset/data/predictions/smc_dataset2/SMC_275.log.q=0.50.full.csv', OFFSET, DURATION)

# %%
print beats
print beats_pred_sum
print beats_pred_med
# Out:
# [  100.   606.  1140.  1657.  2171.]
# [  121.   290.   462.   634.   809.   977.  1150.  1324.  1496.  1668.
#   1848.  2014.  2187.  2356.]
# [  122.   293.   464.   634.   810.   977.  1150.  1325.  1497.  1668.
#   1849.  2016.  2188.  2358.]

# %%
M = librosa.feature.melfb(sr, n_fft=2048, n_mels=128, fmax=8000)
M = M[:,:1025]

# %%
figure(figsize=(8,4))
subplot(311)
specshow(S**(1./3))
xticks([]), yticks([])
vlines(beats, 0, S.shape[0], colors='r')
ylabel('Spectrogram')
subplot(312)
plot(odf_sum(librosa.logamplitude(M.dot(S)))), axis('tight')
xticks([]), yticks([])
vlines(beats_pred_sum, 0, 1, colors='r')
ylabel('Onset-sum')
subplot(313)
plot(odf_med(librosa.logamplitude(M.dot(S)))), axis('tight')
xticks([]), yticks([])
ylabel('Onset-med')
vlines(beats_pred_med, 0, 1, colors='r')
tight_layout()

# %% [markdown]
# # Crunching the SMC paper's results

# %%
import scipy.io
import numpy as np
import glob
import os

# %%
tracks = sorted(map(os.path.basename, glob.glob('/home/bmcfee/git/beat_onset/data/truth/smc_dataset2/*.txt')))
tracks = map(lambda x: os.path.splitext(x)[0], tracks)

# %%
data = scipy.io.loadmat('/home/bmcfee/git/beat_onset/data/smcdata_beatoutput.mat')

# %%
smc_algs = data['name'].squeeze()
smc_anns = data['anns'].squeeze()
smc_pred = data['Beats'].squeeze()
smc_algs = [str(z[0]) for z in map(list, smc_algs)]

# %%
print smc_algs
# Out:
# ['Aubio', 'Beatit', 'Beatroot', 'BeatUJAEN', 'Boeck', 'Davies_standard', 'Degara', 'Ellis', 'Essentia', 'Hainsworth', 'IBT_causal', 'IBT_noncausal', 'Klapuri', 'Lee', 'Scheirer', 'Stark']

# %%
OUTPUT_PATH = '/home/bmcfee/git/beat_onset/data/predictions/smc_dataset2/'

# %%
for alg in range(len(smc_algs)):
    alg_name = smc_algs[alg]
    
    for i in range(len(smc_anns)):
        # Write the prediction file
        preds = smc_pred[alg][i].flatten()
        np.savetxt('%s/%s.%s.csv' % (OUTPUT_PATH, tracks[i], alg_name), preds, fmt='%.03f', delimiter='\n')

# %% [markdown]
# Plotzen

# %%
import cPickle as pickle
import functools
specshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='bone_r')

# %%
with open('/home/bmcfee/git/beat_onset/data/SMC_275.pickle', 'r') as f:
    S, H, P, L = map(np.abs, pickle.load(f)[:4])

# %%
print S.shape
# Out:
# (128, 13750)

# %%
np.diff(BOUNDS) * 64. / 22050
# Out:
# array([ 6.53061224])

# %%
#BOUNDS=(4500,6000)
BOUNDS=(11500,13750)

# %%
figure(figsize=(12,3))
vmin = 0
vmax = (S[:,BOUNDS[0]:BOUNDS[1]]**(1./3)).max()

subplot(141), specshow(S[:,BOUNDS[0]:BOUNDS[1]]**(1./3), vmin=vmin, vmax=vmax), xticks([]), yticks([])#, ylabel('Spectrogram')

xlabel('(a) Full spectrogram')
#subplot(345), plot(odf_sum(librosa.logamplitude(S))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([]), ylabel('Onset-sum')
#subplot(349), plot(odf_med(librosa.logamplitude(S))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([]), ylabel('Onset-median')

subplot(142), specshow(H[:,BOUNDS[0]:BOUNDS[1]]**(1./3), vmin=vmin, vmax=vmax), xticks([]), yticks([])
xlabel('(b) Harmonic')
#subplot(346), plot(odf_sum(librosa.logamplitude(H))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([])
#subplot(3,4,10), plot(odf_med(librosa.logamplitude(H))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([])

subplot(143), specshow(P[:,BOUNDS[0]:BOUNDS[1]]**(1./3), vmin=vmin, vmax=vmax), xticks([]), yticks([])
xlabel('(c) Percussive')
#subplot(347), plot(odf_sum(librosa.logamplitude(P))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([])
#subplot(3,4,11), plot(odf_med(librosa.logamplitude(P))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([])

subplot(144), specshow(L[:,BOUNDS[0]:BOUNDS[1]]**(1./3), vmin=vmin, vmax=vmax), xticks([]), yticks([])
xlabel('(d) Low-rank')
#subplot(348), plot(odf_sum(librosa.logamplitude(L))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([])
#subplot(3,4,12), plot(odf_med(librosa.logamplitude(L))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([])
tight_layout()
savefig('/home/bmcfee/git/beat_onset/paper/figs/specgrams.pdf', format='pdf', pad_inches=0, transparent=True)
pass

# %%
with open('/home/bmcfee/git/beat_onset/data/train4.pickle', 'r') as f:
    S, H, P, L = map(np.abs, pickle.load(f)[:4])

# %%
np.diff(BOUNDS) * 64 / 22050.
# Out:
# array([ 5.07936508])

# %%
np.diff(BOUNDS)
# Out:
# array([1750])

# %%
BOUNDS = (2600, 4350)
#BOUNDS = (-2750, -1000)
figure(figsize=(6,4))
subplot(3,1,1), specshow(S[:,BOUNDS[0]:BOUNDS[1]]**(1./3)), xticks([]), yticks([]), ylabel('Spectrogram')
subplot(3,1,2), plot(odf_sum(librosa.logamplitude(S))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([]), ylabel('Onset-sum')
subplot(3,1,3), plot(odf_med(librosa.logamplitude(S))[BOUNDS[0]:BOUNDS[1]]), axis('tight'), xticks([]), yticks([]), ylabel('Onset-med')
tight_layout()
savefig('/home/bmcfee/git/beat_onset/paper/figs/onsets.pdf', format='pdf', pad_inches=0, transparent=True)
